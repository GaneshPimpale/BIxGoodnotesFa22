# %%
import numpy as np
import scipy.stats as stats
import pandas as pd

import matplotlib .pyplot as plt

# %% [markdown]
# ### Data prep...

# %%
data = "./11-3_AllData.csv"
df = pd.read_csv(data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 56 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   StartDate              145 non-null    object
#  1   EndDate                145 non-null    object
#  2   Status                 145 non-null    object
#  3   IPAddress              144 non-null    object
#  4   Progress               145 non-null    object
#  5   Duration (in seconds)  145 non-null    object
#  6   Finished               145 non-null    object
#  7   RecordedDate           145 non-null    object
#  8   ResponseId             145 non-null    object
#  9   RecipientLastName      2 non-null      object
#  10  RecipientFirstName     2 non-null      object
#  11  RecipientEmail         2 non-null      object
#  12  ExternalReference      2 non-null      object
#  13  LocationLatitude       105 non-null    object
#  14  LocationLongitude      105 non-null    object
#  15  DistributionChannel    145 non-null    object
#  16  UserLanguage           145 non-null    object
#  17  Q_RecaptchaScore       142 non-null    object
#  18  Q1                     131 non-null    object
#  19  Q1_10_TEXT             3 non-null      object
#  20  Q2                     122 non-null    object
#  21  Q2_20_TEXT             21 non-null     object
#  22  Q2_28_TEXT             3 non-null      object
#  23  Q2_36_TEXT             9 non-null      object
#  24  Q2_45_TEXT             9 non-null      object
#  25  Q2_51_TEXT             2 non-null      object
#  26  Q2_53_TEXT             3 non-null      object
#  27  Q3                     119 non-null    object
#  28  Q3_11_TEXT             10 non-null     object
#  29  Q4                     114 non-null    object
#  30  Q4_6_TEXT              7 non-null      object
#  31  Q5                     119 non-null    object
#  32  Q5_8_TEXT              10 non-null     object
#  33  Q6                     115 non-null    object
#  34  Q7                     54 non-null     object
#  35  Q7_20_TEXT             7 non-null      object
#  36  Q7_28_TEXT             2 non-null      object
#  37  Q7_36_TEXT             2 non-null      object
#  38  Q7_45_TEXT             3 non-null      object
#  39  Q7_51_TEXT             2 non-null      object
#  40  Q7_53_TEXT             2 non-null      object
#  41  Q8                     52 non-null     object
#  42  Q8_12_TEXT             3 non-null      object
#  43  Q9                     52 non-null     object
#  44  Q9_7_TEXT              2 non-null      object
#  45  Q10                    53 non-null     object
#  46  Q10_6_TEXT             4 non-null      object
#  47  Q11                    52 non-null     object
#  48  Q11_9_TEXT             2 non-null      object
#  49  Q12                    106 non-null    object
#  50  Q12_5_TEXT             2 non-null      object
#  51  Q13                    107 non-null    object
#  52  Q13_9_TEXT             14 non-null     object
#  53  Q14                    48 non-null     object
#  54  Q15                    102 non-null    object
#  55  Q15_1_TEXT             32 non-null     object
# dtypes: object(56)
# memory usage: 63.6+ KB

# %%
# Get rid of useless columns/rows
df = df.drop(
        columns=['StartDate', 'EndDate', 'IPAddress', 'RecordedDate', 
                'RecipientLastName', 'RecipientFirstName', 'RecipientLastName', 
                'RecipientEmail', 'ExternalReference','DistributionChannel'],
        index=[0, 1]
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 143 entries, 2 to 144
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Status                 143 non-null    object
#  1   Progress               143 non-null    object
#  2   Duration (in seconds)  143 non-null    object
#  3   Finished               143 non-null    object
#  4   ResponseId             143 non-null    object
#  5   LocationLatitude       103 non-null    object
#  6   LocationLongitude      103 non-null    object
#  7   UserLanguage           143 non-null    object
#  8   Q_RecaptchaScore       140 non-null    object
#  9   Q1                     129 non-null    object
#  10  Q1_10_TEXT             1 non-null      object
#  11  Q2                     120 non-null    object
#  12  Q2_20_TEXT             19 non-null     object
#  13  Q2_28_TEXT             1 non-null      object
#  14  Q2_36_TEXT             7 non-null      object
#  15  Q2_45_TEXT             7 non-null      object
#  16  Q2_51_TEXT             0 non-null      object
#  17  Q2_53_TEXT             1 non-null      object
#  18  Q3                     117 non-null    object
#  19  Q3_11_TEXT             8 non-null      object
#  20  Q4                     112 non-null    object
#  21  Q4_6_TEXT              5 non-null      object
#  22  Q5                     117 non-null    object
#  23  Q5_8_TEXT              8 non-null      object
#  24  Q6                     113 non-null    object
#  25  Q7                     52 non-null     object
#  26  Q7_20_TEXT             5 non-null      object
#  27  Q7_28_TEXT             0 non-null      object
#  28  Q7_36_TEXT             0 non-null      object
#  29  Q7_45_TEXT             1 non-null      object
#  30  Q7_51_TEXT             0 non-null      object
#  31  Q7_53_TEXT             0 non-null      object
#  32  Q8                     50 non-null     object
#  33  Q8_12_TEXT             1 non-null      object
#  34  Q9                     50 non-null     object
#  35  Q9_7_TEXT              0 non-null      object
#  36  Q10                    51 non-null     object
#  37  Q10_6_TEXT             2 non-null      object
#  38  Q11                    50 non-null     object
#  39  Q11_9_TEXT             0 non-null      object
#  40  Q12                    104 non-null    object
#  41  Q12_5_TEXT             0 non-null      object
#  42  Q13                    105 non-null    object
#  43  Q13_9_TEXT             12 non-null     object
#  44  Q14                    46 non-null     object
#  45  Q15                    100 non-null    object
#  46  Q15_1_TEXT             30 non-null     object
# dtypes: object(47)
# memory usage: 53.6+ KB

# %%
# Set the ResponseIds as the index value for each response
df.set_index("ResponseId", inplace=True)
df.head()
# Out:
#                            Status Progress Duration (in seconds) Finished  \
# ResponseId
# R_239ymaOz9IwzVY6  Survey Preview      100                    12     True
# R_1i8WxOAA269cEk1      IP Address      100                    55     True
# R_1H60HxqCquIDS0n      IP Address      100                 18592     True
# R_1ghf8xJrVXbbkuJ      IP Address      100                   458     True
# R_1mJIzOkTM39eIoR      IP Address      100                  1166     True
#
#                   LocationLatitude LocationLongitude UserLanguage  \
# ResponseId
# R_239ymaOz9IwzVY6          37.7794         -122.2178           EN
# R_1i8WxOAA269cEk1          37.8657         -122.2571           EN
# R_1H60HxqCquIDS0n          37.8922         -122.2729           EN
# R_1ghf8xJrVXbbkuJ          22.2908          114.1501           EN
# R_1mJIzOkTM39eIoR          37.6609         -122.0491           EN
#
#                      Q_RecaptchaScore                            Q1  \
# ResponseId
# R_239ymaOz9IwzVY6                 NaN                           NaN
# R_1i8WxOAA269cEk1                 NaN                           NaN
# R_1H60HxqCquIDS0n  0.8999999761581421                           NaN
# R_1ghf8xJrVXbbkuJ                   1  Master's student,PhD student
# R_1mJIzOkTM39eIoR                   1         Undergraduate student
#
#                   Q1_10_TEXT  ... Q10_6_TEXT                Q11 Q11_9_TEXT  \
# ResponseId                    ...
# R_239ymaOz9IwzVY6        NaN  ...        NaN                NaN        NaN
# R_1i8WxOAA269cEk1        NaN  ...        NaN   Homework answers        NaN
# R_1H60HxqCquIDS0n        NaN  ...        NaN                NaN        NaN
# R_1ghf8xJrVXbbkuJ        NaN  ...        NaN  Notes you created        NaN
# R_1mJIzOkTM39eIoR        NaN  ...        NaN                NaN        NaN
#
#                                                     Q12 Q12_5_TEXT  \
# ResponseId
# R_239ymaOz9IwzVY6                                   NaN        NaN
# R_1i8WxOAA269cEk1  Small student-made class group chats        NaN
# R_1H60HxqCquIDS0n                                   NaN        NaN
# R_1ghf8xJrVXbbkuJ  Small student-made class group chats        NaN
# R_1mJIzOkTM39eIoR       Student clubs and organizations        NaN
#
#                                               Q13 Q13_9_TEXT  \
# ResponseId
# R_239ymaOz9IwzVY6                             NaN        NaN
# R_1i8WxOAA269cEk1                           Quora        NaN
# R_1H60HxqCquIDS0n  Twitter,Other (please specify)        NaN
# R_1ghf8xJrVXbbkuJ                 Figma Community        NaN
# R_1mJIzOkTM39eIoR                 Instagram,Slack        NaN
#
#                                           Q14  \
# ResponseId
# R_239ymaOz9IwzVY6                         NaN
# R_1i8WxOAA269cEk1                         NaN
# R_1H60HxqCquIDS0n  Neither agree nor disagree
# R_1ghf8xJrVXbbkuJ           Strongly disagree
# R_1mJIzOkTM39eIoR                         NaN
#
#                                                    Q15  \
# ResponseId
# R_239ymaOz9IwzVY6                                  NaN
# R_1i8WxOAA269cEk1                                  NaN
# R_1H60HxqCquIDS0n                                  NaN
# R_1ghf8xJrVXbbkuJ  Yes, if so please enter your email:
# R_1mJIzOkTM39eIoR  Yes, if so please enter your email:
#
#                                      Q15_1_TEXT
# ResponseId
# R_239ymaOz9IwzVY6                           NaN
# R_1i8WxOAA269cEk1                           NaN
# R_1H60HxqCquIDS0n                           NaN
# R_1ghf8xJrVXbbkuJ      mubarak@goodnotesapp.com
# R_1mJIzOkTM39eIoR  juliacunningham@berkeley.edu
#
# [5 rows x 46 columns]

# %%
# Filter spam and incomplete responses
drop_indexes = []
for rID in df.index:
    response = df.loc[rID]
    if response['Finished'] == 'False' or response['Status'] == 'Spam':
        drop_indexes.append(rID)    
df = df.drop(index=drop_indexes)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103 entries, R_239ymaOz9IwzVY6 to R_3HwDJeWJA2Nuujs
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Status                 103 non-null    object
#  1   Progress               103 non-null    object
#  2   Duration (in seconds)  103 non-null    object
#  3   Finished               103 non-null    object
#  4   LocationLatitude       103 non-null    object
#  5   LocationLongitude      103 non-null    object
#  6   UserLanguage           103 non-null    object
#  7   Q_RecaptchaScore       100 non-null    object
#  8   Q1                     100 non-null    object
#  9   Q1_10_TEXT             0 non-null      object
#  10  Q2                     101 non-null    object
#  11  Q2_20_TEXT             16 non-null     object
#  12  Q2_28_TEXT             0 non-null      object
#  13  Q2_36_TEXT             5 non-null      object
#  14  Q2_45_TEXT             5 non-null      object
#  15  Q2_51_TEXT             0 non-null      object
#  16  Q2_53_TEXT             1 non-null      object
#  17  Q3                     100 non-null    object
#  18  Q3_11_TEXT             7 non-null      object
#  19  Q4                     97 non-null     object
#  20  Q4_6_TEXT              5 non-null      object
#  21  Q5                     100 non-null    object
#  22  Q5_8_TEXT              5 non-null      object
#  23  Q6                     100 non-null    object
#  24  Q7                     45 non-null     object
#  25  Q7_20_TEXT             4 non-null      object
#  26  Q7_28_TEXT             0 non-null      object
#  27  Q7_36_TEXT             0 non-null      object
#  28  Q7_45_TEXT             1 non-null      object
#  29  Q7_51_TEXT             0 non-null      object
#  30  Q7_53_TEXT             0 non-null      object
#  31  Q8                     46 non-null     object
#  32  Q8_12_TEXT             1 non-null      object
#  33  Q9                     46 non-null     object
#  34  Q9_7_TEXT              0 non-null      object
#  35  Q10                    47 non-null     object
#  36  Q10_6_TEXT             2 non-null      object
#  37  Q11                    46 non-null     object
#  38  Q11_9_TEXT             0 non-null      object
#  39  Q12                    101 non-null    object
#  40  Q12_5_TEXT             0 non-null      object
#  41  Q13                    102 non-null    object
#  42  Q13_9_TEXT             11 non-null     object
#  43  Q14                    46 non-null     object
#  44  Q15                    100 non-null    object
#  45  Q15_1_TEXT             30 non-null     object
# dtypes: object(46)
# memory usage: 37.8+ KB

# %%
# Define major groupings:
major_groups = {
    'stem':  ['Biology', 'Chemistry', 'Computer Science', 'Earth Science', 'Electrical Engineering', 'Engineering & Technology', 'Geography & Enviornment', 'Mathematics', 'Mechanical Engineering', 'Physics'],
    'h_m': ['Biology', 'Biomedicine $ Pharmacy', 'Dentistry', 'Medicine & Health', 'Nursing', 'Sports & Rehabilitation', 'Veterinary'],
    'ss': ['Anthropology', 'Economics', 'Law', 'Political science', 'Psychology', 'Social Work', 'Sociology'],
    'a_h':  ['Architecture', 'Arts, Media & Design', 'History', 'Journalism & Communication', 'Language & Literature', 'Music & Performing arts', 'Philosophy', 'Religion & Theology'],
    'b_f': ['Accounting & Finance', 'Business & Management', 'Economics', 'Hospitality & Tourism', 'Marketing & Public Relations']
}

# Store response IDs here (majors):
stem_r = []
h_m_r = []
ss_r = []
a_h_r = []
b_f_r = []
other_r = []

# Sore response IDs here (study groups): 
stem_sr = []
h_m_sr = []
ss_sr = []
a_h_sr = []
b_f_sr = []
other_sr = []

# %%
# Sort responses by pesonal major and study group major

for rID in df.index:
    response = df.loc[rID]
    major = response['Q2']
    
    if any(mg == major for mg in major_groups['stem']):
        stem_r.append(rID)
    if any(mg == major for mg in major_groups['h_m']):
        h_m_r.append(rID)
    if any(mg == major for mg in major_groups['ss']):
        ss_r.append(rID)
    if any(mg == major for mg in major_groups['a_h']):
        a_h_r.append(rID)
    if any(mg == major for mg in major_groups['b_f']):
        b_f_r.append(rID)
    else:
        other_r.append(rID)

    if any(mg == major for mg in major_groups['stem']):
        stem_sr.append(rID)
    if any(mg == major for mg in major_groups['h_m']):
        h_m_sr.append(rID)
    if any(mg == major for mg in major_groups['ss']):
        ss_sr.append(rID)
    if any(mg == major for mg in major_groups['a_h']):
        a_h_sr.append(rID)
    if any(mg == major for mg in major_groups['b_f']):
        b_f_sr.append(rID)
    else:
        other_sr.append(rID)

# %% [markdown]
# ### Question: Major vs topic of study in study groups?

# %%
# number of same major vs topic of study (broad group)
same = 0
diff = 0
for rID in df.index:
    if rID in stem_r and rID in stem_sr:
        same += 1
    elif rID in h_m_r and rID in h_m_sr:
        same += 1
    elif rID in ss_r and rID in ss_sr:
        same += 1
    elif rID in a_h_r and rID in a_h_sr:
        same += 1
    elif rID in b_f_r and rID in b_f_sr:
        same += 1
    elif rID in other_r and rID in other_sr:
        same += 1
    else:
        diff += 1
print(same)
print(diff)
# Out:
# 103
# 0

# %%
same = 0
diff = 0
for rID in df.index:
    response = df.loc[rID]
    if response['Q6'] == "Yes":
        major = response['Q2']

# %% [markdown]
# ### Question: Is there a correlation between how notes are taken and how they are shared?
